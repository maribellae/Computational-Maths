# %% [markdown]
# # Макарова Мария Лабораторная 8 11 4

# %%
import matplotlib.pylab as plt
import numpy as np
# %matplotlib inline

# %%
length = 20
h = 0.001 #шаг 
F1 = lambda z : z 
F2 = lambda u : u 
F3 = lambda x,y: -x/(x**2 + y**2)**(3/2) 
F4 = lambda x,y: -y/(x**2 + y**2)**(3/2)

# %% [markdown]
# ### 4 ПОРЯДОК

# %%
length = int(20/h)
x = [0]*(length)
y = [0]*(length)
z = [0]*(length)
u = [0]*(length)
t = [0]*(length)
x[0]=0.5
y[0]=0
z[0]=0
u[0]=1.73
k1=[0]*4
k2=[0]*4
k3=[0]*4
k4=[0]*4

# %%
size= int(20/h)
for i in range(size):
        t[i] = h * i

# %%
for i in range(length-1):
    k1[0] = F1(z[i])
    k2[0] = F2(u[i])
    k3[0] = F3(x[i], y[i])
    k4[0] = F4(x[i], y[i])
        
    k1[1] = F1(z[i]+  h*k3[0]/2)
    k2[1] = F2(u[i] + h*k4[0]/2)
    k3[1] = F3(x[i] + h*k1[0]/2 , y[i] + h*k2[0]/2)
    k4[1] = F4(x[i] + h*k1[0]/2 , y[i] + h*k2[0]/2)
   
    k1[2] = F1(z[i] + h*k3[1]/2)
    k2[2] = F2(u[i] + h*k4[1]/2)
    k3[2] = F3(x[i] + h*k1[1]/2 , y[i] + h*k2[1]/2)
    k4[2] = F4(x[i] + h*k1[1]/2 , y[i] + h*k2[1]/2)

           
    k1[3] = F1(z[i] + h*k3[2])
    k2[3] = F2(u[i] + h*k4[2])
    k3[3] = F3(x[i] + h*k1[2] , y[i] + h*k2[2])
    k4[3] = F4(x[i] + h*k1[2] , y[i] + h*k2[2])

        
    x[i+1] = x[i] + h * (k1[0] + k1[1]*2 + k1[2]*2 + k1[3]) / 6
    y[i+1] = y[i] + h * (k2[0] + k2[1]*2 + k2[2]*2 + k2[3]) / 6
    z[i+1] = z[i] + h * (k3[0] + k3[1]*2 + k3[2]*2 + k3[3]) / 6
    u[i+1] = u[i] + h * (k4[0] + k4[1]*2 + k4[2]*2 + k4[3]) / 6

# %%
fig= plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(t ,x, y)
ax.scatter(t, z, u)
ax.set_xlabel('TIME')
ax.set_ylabel('blue X or orange Z')
ax.set_zlabel('blue Y or orange U');

# %%
plt.figure(figsize = [12,4])
plt.plot(x,y)
plt.plot(z,u)
plt.show()

# %% [markdown]
# ## 3 порядок

# %%
length = int(20/h)
x = [0]*(length)
y = [0]*(length)
z = [0]*(length)
u = [0]*(length)

x[0]=0.5
y[0]=0
z[0]=0
u[0]=1.73
k1=[0]*3
k2=[0]*3
k3=[0]*3
k4=[0]*3

# %%
for i in range(length-1):
    k1[0] = F1(z[i])
    k2[0] = F2(u[i])
    k3[0] = F3(x[i], y[i])
    k4[0] = F4(x[i], y[i])
        
    k1[1] = F1(z[i]+  h*k3[0]/2)
    k2[1] = F2(u[i] + h*k4[0]/2)
    k3[1] = F3(x[i] + h*k1[0]/2 , y[i] + h*k2[0]/2)
    k4[1] = F4(x[i] + h*k1[0]/2 , y[i] + h*k2[0]/2)
   
    k1[2] = F1(z[i] + h*k3[1])
    k2[2] = F2(u[i] + h*k4[1])
    k3[2] = F3(x[i] + h*k1[1] , y[i] + h*k2[1])
    k4[2] = F4(x[i] + h*k1[1] , y[i] + h*k2[1])

           
    x[i+1] = x[i] + h * (k1[0] + k1[1]*4 + k1[2] ) / 6
    y[i+1] = y[i] + h * (k2[0] + k2[1]*4 + k2[2]) / 6
    z[i+1] = z[i] + h * (k3[0] + k3[1]*4 + k3[2]) / 6
    u[i+1] = u[i] + h * (k4[0] + k4[1]*4 + k4[2]) / 6

# %%
fig= plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(t ,x, y)
ax.scatter(t, z, u)
ax.set_xlabel('TIME')
ax.set_ylabel('blue X or orange Z')
ax.set_zlabel('blue Y or orange U');

# %%
plt.figure(figsize = [12,4])
plt.plot(x,y)
plt.plot(z,u)
plt.xlabel('blue X or orange Z')
plt.ylabel('blue Y or orange U')
plt.show()

# %% [markdown]
# ## 2 порядок

# %%
length = int(20/h)
x = [0]*(length)
y = [0]*(length)
z = [0]*(length)
u = [0]*(length)
x[0]=0.5
y[0]=0
z[0]=0
u[0]=1.73
k1=[0]*2
k2=[0]*2
k3=[0]*2
k4=[0]*2

# %%
for i in range(length-1):
    k1[0] = F1(z[i])
    k2[0] = F2(u[i])
    k3[0] = F3(x[i], y[i])
    k4[0] = F4(x[i], y[i])
        
    k1[1] = F1(z[i]+  h*k3[0]/2)
    k2[1] = F2(u[i] + h*k4[0]/2)
    k3[1] = F3(x[i] + h*k1[0]/2 , y[i] + h*k2[0]/2)
    k4[1] = F4(x[i] + h*k1[0]/2 , y[i] + h*k2[0]/2)
   
           
    x[i+1] = x[i] + h * k1[1] 
    y[i+1] = y[i] + h * k2[1]
    z[i+1] = z[i] + h * k3[1]
    u[i+1] = u[i] + h * k4[1]

# %%
fig= plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(t ,x, y)
ax.scatter(t, z, u)
ax.set_xlabel('TIME')
ax.set_ylabel('blue X or orange Z')
ax.set_zlabel('blue Y or orange U');

# %%
plt.figure(figsize = [12,4])
plt.plot(x,y)
plt.plot(z,u)
plt.xlabel('blue X or orange Z')
plt.ylabel('blue Y or orange U')
plt.show()

# %% [markdown]
# ## 1 порядок

# %%
length = int(20/h)
x = [0]*(length)
y = [0]*(length)
z = [0]*(length)
u = [0]*(length)
x[0]=0.5
y[0]=0
z[0]=0
u[0]=1.73
k1=[0]
k2=[0]
k3=[0]
k4=[0]

# %%
for i in range(length-1):
    k1[0] = F1(z[i])
    k2[0] = F2(u[i])
    k3[0] = F3(x[i], y[i])
    k4[0] = F4(x[i], y[i])

           
    x[i+1] = x[i] + h * k1[0] 
    y[i+1] = y[i] + h * k2[0]
    z[i+1] = z[i] + h * k3[0]
    u[i+1] = u[i] + h * k4[0]

# %%
fig= plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(t ,x, y)
ax.scatter(t, z, u)
ax.set_xlabel('TIME')
ax.set_ylabel('blue X or orange Z')
ax.set_zlabel('blue Y or orange U');

# %%
plt.figure(figsize = [12,4])
plt.plot(x,y)
plt.plot(z,u)
plt.xlabel('blue X or orange Z')
plt.ylabel('blue Y or orange U')
plt.show()

# %% [markdown]
# Выше я привела решение при шаге h=0.001, а теперь попробую взять, например, для 1 и 4 порядка  h = 0.1 и h = 0.01

# %%
h = 0.01

length = int(20/h)
x = [0]*(length)
y = [0]*(length)
z = [0]*(length)
u = [0]*(length)
t = [0]*(length)
x[0]=0.5
y[0]=0
z[0]=0
u[0]=1.73
k1=[0]*4
k2=[0]*4
k3=[0]*4
k4=[0]*4

size= int(20/h)
for i in range(size):
        t[i] = h * i   
        
        
for i in range(length-1):
    k1[0] = F1(z[i])
    k2[0] = F2(u[i])
    k3[0] = F3(x[i], y[i])
    k4[0] = F4(x[i], y[i])
        
    k1[1] = F1(z[i]+  h*k3[0]/2)
    k2[1] = F2(u[i] + h*k4[0]/2)
    k3[1] = F3(x[i] + h*k1[0]/2 , y[i] + h*k2[0]/2)
    k4[1] = F4(x[i] + h*k1[0]/2 , y[i] + h*k2[0]/2)
   
    k1[2] = F1(z[i] + h*k3[1]/2)
    k2[2] = F2(u[i] + h*k4[1]/2)
    k3[2] = F3(x[i] + h*k1[1]/2 , y[i] + h*k2[1]/2)
    k4[2] = F4(x[i] + h*k1[1]/2 , y[i] + h*k2[1]/2)

           
    k1[3] = F1(z[i] + h*k3[2])
    k2[3] = F2(u[i] + h*k4[2])
    k3[3] = F3(x[i] + h*k1[2] , y[i] + h*k2[2])
    k4[3] = F4(x[i] + h*k1[2] , y[i] + h*k2[2])

        
    x[i+1] = x[i] + h * (k1[0] + k1[1]*2 + k1[2]*2 + k1[3]) / 6
    y[i+1] = y[i] + h * (k2[0] + k2[1]*2 + k2[2]*2 + k2[3]) / 6
    z[i+1] = z[i] + h * (k3[0] + k3[1]*2 + k3[2]*2 + k3[3]) / 6
    u[i+1] = u[i] + h * (k4[0] + k4[1]*2 + k4[2]*2 + k4[3]) / 6
    
x4= x
y4 = y
z4= z
u4= u

# %%
length = int(20/h)
x = [0]*(length)
y = [0]*(length)
z = [0]*(length)
u = [0]*(length)
x[0]=0.5
y[0]=0
z[0]=0
u[0]=1.73
k1=[0]
k2=[0]
k3=[0]
k4=[0]

for i in range(length-1):
    k1[0] = F1(z[i])
    k2[0] = F2(u[i])
    k3[0] = F3(x[i], y[i])
    k4[0] = F4(x[i], y[i])

           
    x[i+1] = x[i] + h * k1[0] 
    y[i+1] = y[i] + h * k2[0]
    z[i+1] = z[i] + h * k3[0]
    u[i+1] = u[i] + h * k4[0]


plt.figure(figsize = [12,4])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.plot(z,u)
plt.xlabel('blue X or orange Z')
plt.ylabel('blue Y or orange U')
plt.title("1 порядок h = 0.01")
plt.subplot(1,2,2)
plt.plot(x4,y4)
plt.plot(z4,u4)
plt.title("4 порядок h = 0.01")
plt.xlabel('blue X or orange Z')
plt.ylabel('blue Y or orange U')

plt.show()

# %%
h = 0.1

length = int(20/h)
x = [0]*(length)
y = [0]*(length)
z = [0]*(length)
u = [0]*(length)
t = [0]*(length)
x[0]=0.5
y[0]=0
z[0]=0
u[0]=1.73
k1=[0]*4
k2=[0]*4
k3=[0]*4
k4=[0]*4

size= int(20/h)
for i in range(size):
        t[i] = h * i   
        
        
for i in range(length-1):
    k1[0] = F1(z[i])
    k2[0] = F2(u[i])
    k3[0] = F3(x[i], y[i])
    k4[0] = F4(x[i], y[i])
        
    k1[1] = F1(z[i]+  h*k3[0]/2)
    k2[1] = F2(u[i] + h*k4[0]/2)
    k3[1] = F3(x[i] + h*k1[0]/2 , y[i] + h*k2[0]/2)
    k4[1] = F4(x[i] + h*k1[0]/2 , y[i] + h*k2[0]/2)
   
    k1[2] = F1(z[i] + h*k3[1]/2)
    k2[2] = F2(u[i] + h*k4[1]/2)
    k3[2] = F3(x[i] + h*k1[1]/2 , y[i] + h*k2[1]/2)
    k4[2] = F4(x[i] + h*k1[1]/2 , y[i] + h*k2[1]/2)

           
    k1[3] = F1(z[i] + h*k3[2])
    k2[3] = F2(u[i] + h*k4[2])
    k3[3] = F3(x[i] + h*k1[2] , y[i] + h*k2[2])
    k4[3] = F4(x[i] + h*k1[2] , y[i] + h*k2[2])

        
    x[i+1] = x[i] + h * (k1[0] + k1[1]*2 + k1[2]*2 + k1[3]) / 6
    y[i+1] = y[i] + h * (k2[0] + k2[1]*2 + k2[2]*2 + k2[3]) / 6
    z[i+1] = z[i] + h * (k3[0] + k3[1]*2 + k3[2]*2 + k3[3]) / 6
    u[i+1] = u[i] + h * (k4[0] + k4[1]*2 + k4[2]*2 + k4[3]) / 6
    
        
x4= x
y4 = y
z4= z
u4= u

# %%
length = int(20/h)
x = [0]*(length)
y = [0]*(length)
z = [0]*(length)
u = [0]*(length)
x[0]=0.5
y[0]=0
z[0]=0
u[0]=1.73
k1=[0]
k2=[0]
k3=[0]
k4=[0]

for i in range(length-1):
    k1[0] = F1(z[i])
    k2[0] = F2(u[i])
    k3[0] = F3(x[i], y[i])
    k4[0] = F4(x[i], y[i])

           
    x[i+1] = x[i] + h * k1[0] 
    y[i+1] = y[i] + h * k2[0]
    z[i+1] = z[i] + h * k3[0]
    u[i+1] = u[i] + h * k4[0]


plt.figure(figsize = [12,4])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.plot(z,u)
plt.xlabel('blue X or orange Z')
plt.ylabel('blue Y or orange U')
plt.title("1 порядок h = 0.1")
plt.subplot(1,2,2)
plt.plot(x4,y4)
plt.plot(z4,u4)
plt.title("4 порядок h = 0.1")
plt.xlabel('blue X or orange Z')
plt.ylabel('blue Y or orange U')

plt.show()

# %% [markdown]
# Получается, что по мере уменьшения шага h картина становится все точнее и точнее. При h=0.001 картинки даже практически идентичны для всех порядков от 1 до 4.

# %% [markdown]
# Конец:)
